# %% [markdown]
# <a href="https://colab.research.google.com/github/eliba12/Deep-Learning-GEN/blob/main%2FDeep-Learning-%26-GEN/Chatbot_websites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install langchain
 # !pip install faiss-cpu
 # !pip install openai
 # !pip install langchain_community
 # !pip install unstructured
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 33.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.4 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=174a6ebf99324b6178c9bb79d2124ce86bc784f16a3c713001af9cf041ed4866
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR-OPENAI_API_KEY"

# %%
URLS = [
    'https://www.mosaicml.com/blog/mpt-7b',
    'https://stability.ai/blog/stability-ai-launches-the-first-of-its-stablelm-suite-of-language-models',
    'https://lmsys.org/blog/2023-03-30-vicuna/',
    'https://www.mosaicml.com/blog/mpt-7b',
    'https:///root/nltk_data/tokenizers/punkt/PY3_tab',
    'https://lmsys.org/blog/2023-03-30-vicuna/',
]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from langchain.document_loaders.url import UnstructuredURLLoader
loaders = UnstructuredURLLoader(urls=URLS)
data = loaders.load()
# Out:
# ERROR:langchain_community.document_loaders.url:Error fetching or processing https://www.mosaicml.com/blog/mpt-7b, exception: No such file or directory: '/root/nltk_data/tokenizers/punkt/PY3_tab'
# ERROR:langchain_community.document_loaders.url:Error fetching or processing https://stability.ai/blog/stability-ai-launches-the-first-of-its-stablelm-suite-of-language-models, exception: No such file or directory: '/root/nltk_data/tokenizers/punkt/PY3_tab'
# ERROR:langchain_community.document_loaders.url:Error fetching or processing https://lmsys.org/blog/2023-03-30-vicuna/, exception: No such file or directory: '/root/nltk_data/tokenizers/punkt/PY3_tab'
# ERROR:langchain_community.document_loaders.url:Error fetching or processing https://www.mosaicml.com/blog/mpt-7b, exception: No such file or directory: '/root/nltk_data/tokenizers/punkt/PY3_tab'
# ...

# %%
data
# Out:
# []

# %%
docs
# Out:
# []

# %%
# Text Splitter
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(separator='\n',
                                      chunk_size=1000,
                                      chunk_overlap=200)


docs = text_splitter.split_documents(data)

# %%
len(docs)
# Out:
# 0

# %%
import pickle
import pickle
import faiss
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x79cf5c1d4f40>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x79cf5c19c4c0>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='YOUR-OPENAI_API_KEY', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
 vectorStore_openAI = FAISS.from_documents(docs, embeddings)

  with open("faiss_store_openai.pkl", "wb") as f:
     pickle.dump(vectorStore_openAI, f)
# Out:
#   File "<ipython-input-78-319b72aae0a5>", line 3
#     with open("faiss_store_openai.pkl", "wb") as f:
#     ^
# IndentationError: unexpected indent

# %%
with open("faiss_store_openai.pkl", "rb") as f:
    VectorStore = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-8e8ca91274fb> in <cell line: 1>()
# ----> 1 with open("faiss_store_openai.pkl", "rb") as f:
#       2     VectorStore = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'faiss_store_openai.pkl'

# %%
VectorStore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-fcb51b0bf755> in <cell line: 1>()
# ----> 1 VectorStore
#
# NameError: name 'VectorStore' is not defined

# %%
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains.question_answering import load_qa_chain
from langchain import OpenAI

# %%
llm=OpenAI(temperature=0, model_name='')
# Out:
# <ipython-input-40-cd8c39c9110f>:1: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm=OpenAI(temperature=0, model_name='')

# %%
llm
# Out:
# OpenAI(client=<openai.resources.completions.Completions object at 0x79cf5c8bd4b0>, async_client=<openai.resources.completions.AsyncCompletions object at 0x79cf5c359c90>, model_name='', temperature=0.0, model_kwargs={}, openai_api_key='YOUR-OPENAI_API_KEY', openai_proxy='', logit_bias={})

# %%
chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=VectorStore.as_retriever())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-beee6ca19548> in <cell line: 1>()
# ----> 1 chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=VectorStore.as_retriever())
#
# NameError: name 'VectorStore' is not defined

# %%
chain({"question": "How big is stableLM?"}, return_only_outputs=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d2e7933da02e> in <cell line: 1>()
# ----> 1 chain({"question": "How big is stableLM?"}, return_only_outputs=True)
#
# NameError: name 'chain' is not defined

# %%
chain({"question": "How good is Vicuna?"}, return_only_outputs=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-aef03a88666a> in <cell line: 1>()
# ----> 1 chain({"question": "How good is Vicuna?"}, return_only_outputs=True)
#
# NameError: name 'chain' is not defined

# %%
chain({"question": "Which MPT-7B model is the bast one?"}, return_only_outputs=True)
# Out:
# {'answer': ' The best MPT-7B model is MPT-7B-Instruct, which was trained on 1 trillion tokens.\n',
#  'sources': 'https://www.mosaicml.com/blog/mpt-7b'}
